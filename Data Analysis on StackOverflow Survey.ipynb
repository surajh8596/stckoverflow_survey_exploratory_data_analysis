# %%
import pandas as pd
import numpy as np
import math
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
stack=pd.read_csv('D:\\PGP IN DATA SCIENCE with Careerera\\Files\\stackoverflow-survey_results_public.csv')

# %%
stack
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
stack_schema=pd.read_csv('D:\\PGP IN DATA SCIENCE with Careerera\\Files\\survey_results_schema.csv')

# %%
stack_schema
# Out:
#                 Column                                       QuestionText
# 0           Respondent  Randomized respondent ID number (not in order ...
# 1           MainBranch  Which of the following options best describes ...
# 2             Hobbyist                            Do you code as a hobby?
# 3                  Age  What is your age (in years)? If you prefer not...
# 4           Age1stCode  At what age did you write your first line of c...
# ..                 ...                                                ...
# 56  WebframeWorkedWith  Which web frameworks have you done extensive d...
# 57       WelcomeChange  Compared to last year, how welcome do you feel...
# 58         WorkWeekHrs  On average, how many hours per week do you wor...
# 59           YearsCode  Including any education, how many years have y...
# 60        YearsCodePro  NOT including education, how many years have y...
#
# [61 rows x 2 columns]

# %%
pd.options.display.max_columns=80

# %%
stack.head(3)
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
#
#                                           Employment             Country  \
# 0  Independent contractor, freelancer, or self-em...            Slovakia
# 1                                 Student, full-time         Netherlands
# 2                                 Student, full-time  Russian Federation
#
#   US_State UK_Country                                            EdLevel  \
# 0      NaN        NaN  Secondary school (e.g. American high school, G...
# 1      NaN        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2      NaN        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#       Age1stCode                                          LearnCode YearsCode  \
# ...

# %%
stack.shape
# Out:
# (83439, 48)

# %%
stack.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83439 entries, 0 to 83438
# Data columns (total 48 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ResponseId                    83439 non-null  int64
#  1   MainBranch                    83439 non-null  object
#  2   Employment                    83323 non-null  object
#  3   Country                       83439 non-null  object
#  4   US_State                      14920 non-null  object
#  5   UK_Country                    4418 non-null   object
#  6   EdLevel                       83126 non-null  object
#  7   Age1stCode                    83243 non-null  object
#  8   LearnCode                     82963 non-null  object
#  9   YearsCode                     81641 non-null  object
#  10  YearsCodePro                  61216 non-null  object
#  11  DevType                       66484 non-null  object
# ...

# %%
stack.set_index('ResponseId').head(3)
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# 3                                          Student, full-time
#
#                        Country US_State UK_Country  \
# ResponseId
# 1                     Slovakia      NaN        NaN
# 2                  Netherlands      NaN        NaN
# 3           Russian Federation      NaN        NaN
#
#                                                       EdLevel     Age1stCode  \
# ResponseId
# 1           Secondary school (e.g. American high school, G...  18 - 24 years
# ...

# %%
stack['Employment'].nunique()
# Out:
# 9

# %%
stack['Employment'].unique()
# Out:
# array(['Independent contractor, freelancer, or self-employed',
#        'Student, full-time', 'Employed full-time', 'Student, part-time',
#        'I prefer not to say', 'Employed part-time',
#        'Not employed, but looking for work', 'Retired',
#        'Not employed, and not looking for work', nan], dtype=object)

# %%
stack.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#        'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
stack_schema['Column']
# Out:
# 0             Respondent
# 1             MainBranch
# 2               Hobbyist
# 3                    Age
# 4             Age1stCode
#              ...
# 56    WebframeWorkedWith
# 57         WelcomeChange
# 58           WorkWeekHrs
# 59             YearsCode
# 60          YearsCodePro
# Name: Column, Length: 61, dtype: object

# %%
stack_schema.set_index('Column')
# Out:
#                                                          QuestionText
# Column
# Respondent          Randomized respondent ID number (not in order ...
# MainBranch          Which of the following options best describes ...
# Hobbyist                                      Do you code as a hobby?
# Age                 What is your age (in years)? If you prefer not...
# Age1stCode          At what age did you write your first line of c...
# ...                                                               ...
# WebframeWorkedWith  Which web frameworks have you done extensive d...
# WelcomeChange       Compared to last year, how welcome do you feel...
# WorkWeekHrs         On average, how many hours per week do you wor...
# YearsCode           Including any education, how many years have y...
# YearsCodePro        NOT including education, how many years have y...
#
# [61 rows x 1 columns]

# %%
stack_schema.iloc[2,1]
# Out:
# 'Do you code as a hobby?'

# %%
stack.describe()
# Out:
#          ResponseId     CompTotal  ConvertedCompYearly
# count  83439.000000  4.718300e+04         4.684400e+04
# mean   41720.000000  2.119407e+69         1.184262e+05
# std    24086.908893  4.603702e+71         5.272944e+05
# min        1.000000  0.000000e+00         1.000000e+00
# 25%    20860.500000  1.600000e+04         2.702500e+04
# 50%    41720.000000  6.700000e+04         5.621100e+04
# 75%    62579.500000  1.400000e+05         1.000000e+05
# max    83439.000000  1.000000e+74         4.524131e+07

# %%
stack.describe(include='O')
# Out:
#                             MainBranch          Employment  \
# count                            83439               83323
# unique                               6                   9
# top     I am a developer by profession  Employed full-time
# freq                             58153               53584
#
#                          Country    US_State UK_Country  \
# count                      83439       14920       4418
# unique                       181          55          4
# top     United States of America  California    England
# freq                       15288        2163       3915
#
#                                              EdLevel     Age1stCode LearnCode  \
# count                                          83126          83243     82963
# unique                                             9              9       458
# top     Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years    School
# ...

# %%
stack.Gender.unique()
# Out:
# array(['Man', 'Prefer not to say', 'Woman',
#        'Non-binary, genderqueer, or gender non-conforming',
#        'Man;Or, in your own words:', nan,
#        'Woman;Non-binary, genderqueer, or gender non-conforming',
#        'Man;Non-binary, genderqueer, or gender non-conforming',
#        'Or, in your own words:', 'Man;Woman',
#        'Man;Woman;Non-binary, genderqueer, or gender non-conforming;Or, in your own words:',
#        'Non-binary, genderqueer, or gender non-conforming;Or, in your own words:',
#        'Woman;Or, in your own words:',
#        'Man;Woman;Non-binary, genderqueer, or gender non-conforming',
#        'Man;Non-binary, genderqueer, or gender non-conforming;Or, in your own words:',
#        'Woman;Non-binary, genderqueer, or gender non-conforming;Or, in your own words:',
#        'Man;Woman;Or, in your own words:'], dtype=object)

# %%
stack.value_counts('US_State')
# Out:
# US_State
# California                              2163
# Texas                                   1023
# New York                                 961
# Washington                               932
# Massachusetts                            624
# Florida                                  613
# Illinois                                 587
# Colorado                                 549
# Pennsylvania                             499
# Virginia                                 453
# Ohio                                     448
# Utah                                     415
# North Carolina                           403
# Michigan                                 381
# Oregon                                   375
# Minnesota                                359
# Georgia                                  356
# Maryland                                 350
# New Jersey                               347
# Wisconsin                                266
# Arizona                                  261
# ...

# %%
male=stack[stack['Gender']=='Man']

# %%
male.head(3)
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
#
#                                           Employment             Country  \
# 0  Independent contractor, freelancer, or self-em...            Slovakia
# 1                                 Student, full-time         Netherlands
# 2                                 Student, full-time  Russian Federation
#
#   US_State UK_Country                                            EdLevel  \
# 0      NaN        NaN  Secondary school (e.g. American high school, G...
# 1      NaN        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2      NaN        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#       Age1stCode                                          LearnCode YearsCode  \
# ...

# %%
male.set_index('Gender').head(3)
# Out:
#         ResponseId                                         MainBranch  \
# Gender
# Man              1                     I am a developer by profession
# Man              2             I am a student who is learning to code
# Man              3  I am not primarily a developer, but I write co...
#
#                                                Employment             Country  \
# Gender
# Man     Independent contractor, freelancer, or self-em...            Slovakia
# Man                                    Student, full-time         Netherlands
# Man                                    Student, full-time  Russian Federation
#
#        US_State UK_Country                                            EdLevel  \
# Gender
# Man         NaN        NaN  Secondary school (e.g. American high school, G...
# Man         NaN        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# Man         NaN        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
# ...

# %%
## sample data

# %%
people = {
    "first": ["Corey", 'Jane', 'John'], 
    "last": ["Schafer", 'Doe', 'Doe'], 
    "email": ["CoreyMSchafer@gmail.com", 'JaneDoe@email.com', 'JohnDoe@email.com']
}

# %%
people['email']
# Out:
# ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com']

# %%
df=pd.DataFrame(people)

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df['first']
# Out:
# 0    Corey
# 1     Jane
# 2     John
# Name: first, dtype: object

# %%
df[['first','last']]
# Out:
#    first     last
# 0  Corey  Schafer
# 1   Jane      Doe
# 2   John      Doe

# %%
df.iloc[0,1]
# Out:
# 'Schafer'

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df.iloc[1,0]
# Out:
# 'Jane'

# %%
df.iloc[0:3,0:1]
# Out:
#    first
# 0  Corey
# 1   Jane
# 2   John

# %%
a=df.iloc[1,0:2]='suraj','honkamble'

# %%
df
# Out:
#    first       last                    email
# 0  Corey    Schafer  CoreyMSchafer@gmail.com
# 1  suraj  honkamble        JaneDoe@email.com
# 2   John        Doe        JohnDoe@email.com

# %%
df.set_index('email', inplace=True)

# %%
df
# Out:
#                          first     last
# email
# CoreyMSchafer@gmail.com  Corey  Schafer
# JaneDoe@email.com         Jane      Doe
# JohnDoe@email.com         John      Doe

# %%
df.index
# Out:
# Index(['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com'], dtype='object', name='email')

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                      email  first     last
# 0  CoreyMSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@email.com   Jane      Doe
# 2        JohnDoe@email.com   John      Doe

# %%
filt=df[df['last']=='Doe']

# %%
filt
# Out:
#                email first last
# 1  JaneDoe@email.com  Jane  Doe
# 2  JohnDoe@email.com  John  Doe

# %%
filt1=df[(df['first']=='John') & (df['last']=='Doe')]

# %%
filt1
# Out:
#                email first last
# 2  JohnDoe@email.com  John  Doe

# %%
df
# Out:
#                      email  first     last
# 0  CoreyMSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@email.com   Jane      Doe
# 2        JohnDoe@email.com   John      Doe

# %%
df.rename({'first':'FIRST','last':'LAST','email':'E-mail'}, axis=1, inplace=True)

# %%
df
# Out:
#                     E-mail  FIRST     LAST
# 0  CoreyMSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@email.com   Jane      Doe
# 2        JohnDoe@email.com   John      Doe

# %%
df.loc[1]='Suraj'

# %%
df
# Out:
#                     E-mail  FIRST     LAST      1
# 0  CoreyMSchafer@gmail.com  Corey  Schafer    NaN
# 1                    Suraj  Suraj    Suraj  Suraj
# 2        JohnDoe@email.com   John      Doe    NaN

# %%
df.rename({1:'full name'},axis=1, inplace=True)

# %%
df.rename({'full name':1},axis=0, inplace=True)

# %%
df
# Out:
#                     E-mail  FIRST     LAST full name
# 0  CoreyMSchafer@gmail.com  Corey  Schafer       NaN
# 1                    Suraj  Suraj    Suraj     Suraj
# 2        JohnDoe@email.com   John      Doe       NaN

# %%
df.loc[0,'full name']='CS'

# %%
df
# Out:
#                     E-mail  FIRST     LAST full name
# 0  CoreyMSchafer@gmail.com  Corey  Schafer        CS
# 1                    Suraj  Suraj    Suraj     Suraj
# 2        JohnDoe@email.com   John      Doe       NaN

# %%
df.loc[1,'E-mail']='surajh@gmail.com'

# %%
df.at[1,'LAST']='h'

# %%
df.at[2,'full name']='JD'

# %%
df
# Out:
#                     E-mail  FIRST     LAST full name
# 0  CoreyMSchafer@gmail.com  Corey  Schafer        CS
# 1         surajh@gmail.com  Suraj        h     Suraj
# 2        JohnDoe@email.com   John      Doe        JD

# %%
df.at[1,'full name']='SH'

# %%
df
# Out:
#                     E-mail  FIRST     LAST full name
# 0  CoreyMSchafer@gmail.com  Corey  Schafer        CS
# 1         surajh@gmail.com  Suraj        h        SH
# 2        JohnDoe@email.com   John      Doe        JD

# %%
df['full Name']=df['FIRST']+ ' ' +df['LAST']

# %%
df
# Out:
#                     E-mail  FIRST     LAST full name      full Name
# 0  CoreyMSchafer@gmail.com  Corey  Schafer        CS  Corey Schafer
# 1         surajh@gmail.com  Suraj        h        SH        Suraj h
# 2        JohnDoe@email.com   John      Doe        JD       John Doe

# %%
df
# Out:
#                     E-mail  FIRST     LAST full name      full Name
# 0  CoreyMSchafer@gmail.com  Corey  Schafer        CS  Corey Schafer
# 1         surajh@gmail.com  Suraj        h        SH        Suraj h
# 2        JohnDoe@email.com   John      Doe        JD       John Doe

# %%
df
# Out:
#                     E-mail  FIRST     LAST full name      full Name
# 0  CoreyMSchafer@gmail.com  Corey  Schafer        CS  Corey Schafer
# 1         surajh@gmail.com  Suraj        h        SH        Suraj h
# 2        JohnDoe@email.com   John      Doe        JD       John Doe

# %%
df.append({'E-mail':'ramujadhav@gmail.com','FIRST':'Ramu','LAST':'Jadhav','full name':'RJ','full Name':'Ramu Jadhav'}, ignore_index='True' )
# Out:
#                     E-mail  FIRST     LAST full name      full Name
# 0  CoreyMSchafer@gmail.com  Corey  Schafer        CS  Corey Schafer
# 1         surajh@gmail.com  Suraj        h        SH        Suraj h
# 2        JohnDoe@email.com   John      Doe        JD       John Doe
# 3     ramujadhav@gmail.com   Ramu   Jadhav        RJ    Ramu Jadhav

# %%
df.append({'First':'Suman'},ignore_index=True)
# Out:
#                     E-mail  FIRST     LAST full name      full Name  First
# 0  CoreyMSchafer@gmail.com  Corey  Schafer        CS  Corey Schafer    NaN
# 1         surajh@gmail.com  Suraj        h        SH        Suraj h    NaN
# 2        JohnDoe@email.com   John      Doe        JD       John Doe    NaN
# 3                      NaN    NaN      NaN       NaN            NaN  Suman

# %%
df.sort_values(by='full Name')
# Out:
#                     E-mail  FIRST     LAST full name      full Name
# 0  CoreyMSchafer@gmail.com  Corey  Schafer        CS  Corey Schafer
# 2        JohnDoe@email.com   John      Doe        JD       John Doe
# 1         surajh@gmail.com  Suraj        h        SH        Suraj h

# %%
stack
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
stack.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#        'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
stack['Age']
# Out:
# 0        25-34 years old
# 1        18-24 years old
# 2        18-24 years old
# 3        35-44 years old
# 4        25-34 years old
#               ...
# 83434    25-34 years old
# 83435    18-24 years old
# 83436    25-34 years old
# 83437    25-34 years old
# 83438    18-24 years old
# Name: Age, Length: 83439, dtype: object

# %%
stack.loc[0:4,'Age':'Sexuality']
# Out:
#                Age Gender Trans                Sexuality
# 0  25-34 years old    Man    No  Straight / Heterosexual
# 1  18-24 years old    Man    No  Straight / Heterosexual
# 2  18-24 years old    Man    No        Prefer not to say
# 3  35-44 years old    Man    No  Straight / Heterosexual
# 4  25-34 years old    Man    No                      NaN

# %%
stack.set_index('ResponseId', inplace=True)

# %%
stack
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 83435                          I am a developer by profession
# 83436                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
# 83439                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# ...

# %%
stack_schema.set_index('Column', inplace=True)

# %%
stack_schema
# Out:
#                 Column                                       QuestionText
# 0           Respondent  Randomized respondent ID number (not in order ...
# 1           MainBranch  Which of the following options best describes ...
# 2             Hobbyist                            Do you code as a hobby?
# 3                  Age  What is your age (in years)? If you prefer not...
# 4           Age1stCode  At what age did you write your first line of c...
# ..                 ...                                                ...
# 56  WebframeWorkedWith  Which web frameworks have you done extensive d...
# 57       WelcomeChange  Compared to last year, how welcome do you feel...
# 58         WorkWeekHrs  On average, how many hours per week do you wor...
# 59           YearsCode  Including any education, how many years have y...
# 60        YearsCodePro  NOT including education, how many years have y...
#
# [61 rows x 2 columns]

# %%
stack_schema.sort_index(inplace=True)

# %%
stack_schema
# Out:
#                 Column                                       QuestionText
# 0           Respondent  Randomized respondent ID number (not in order ...
# 1           MainBranch  Which of the following options best describes ...
# 2             Hobbyist                            Do you code as a hobby?
# 3                  Age  What is your age (in years)? If you prefer not...
# 4           Age1stCode  At what age did you write your first line of c...
# ..                 ...                                                ...
# 56  WebframeWorkedWith  Which web frameworks have you done extensive d...
# 57       WelcomeChange  Compared to last year, how welcome do you feel...
# 58         WorkWeekHrs  On average, how many hours per week do you wor...
# 59           YearsCode  Including any education, how many years have y...
# 60        YearsCodePro  NOT including education, how many years have y...
#
# [61 rows x 2 columns]

# %%
stack_schema.loc['Hobbyist','QuestionText']
# Out:
# 'Do you code as a hobby?'

# %%
stack.columns
# Out:
# Index(['MainBranch', 'Employment', 'Country', 'US_State', 'UK_Country',
#        'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode', 'YearsCodePro',
#        'DevType', 'OrgSize', 'Currency', 'CompTotal', 'CompFreq',
#        'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
stack['SOAccount']
# Out:
# ResponseId
# 1        Yes
# 2        Yes
# 3        Yes
# 4        Yes
# 5        Yes
#         ...
# 83435     No
# 83436    Yes
# 83437    Yes
# 83438    Yes
# 83439    Yes
# Name: SOAccount, Length: 83439, dtype: object

# %%
trans=stack[stack['Trans']=='Yes']

# %%
trans
# Out:
#                                         MainBranch  \
# ResponseId
# 60                  I am a developer by profession
# 97                  I am a developer by profession
# 172                 I am a developer by profession
# 340                    I code primarily as a hobby
# 342                    I code primarily as a hobby
# ...                                            ...
# 83050               I am a developer by profession
# 83110               I am a developer by profession
# 83232               I am a developer by profession
# 83361       I am a student who is learning to code
# 83430                  I code primarily as a hobby
#
#                                                    Employment  \
# ResponseId
# 60                                         Student, full-time
# 97                                         Employed full-time
# 172                                        Employed full-time
# 340                    Not employed, and not looking for work
# ...

# %%
stack['LanguageHaveWorkedWith']
# Out:
# ResponseId
# 1        C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 2                                    JavaScript;Python
# 3                             Assembly;C;Python;R;Rust
# 4                                JavaScript;TypeScript
# 5                       Bash/Shell;HTML/CSS;Python;SQL
#                              ...
# 83435                               Clojure;Kotlin;SQL
# 83436                                              NaN
# 83437                               Groovy;Java;Python
# 83438             Bash/Shell;JavaScript;Node.js;Python
# 83439           Delphi;Elixir;HTML/CSS;Java;JavaScript
# Name: LanguageHaveWorkedWith, Length: 83439, dtype: object

# %%
filt2=stack[stack['LanguageHaveWorkedWith'].str.contains('Python',na=False)]

# %%
filt2
# Out:
#                                                    MainBranch  \
# ResponseId
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 5                              I am a developer by profession
# 6                      I am a student who is learning to code
# 10                             I am a developer by profession
# ...                                                       ...
# 83430                             I code primarily as a hobby
# 83431                          I am a developer by profession
# 83432                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 2                                          Student, full-time
# 3                                          Student, full-time
# ...

# %%
china=trans[trans['Country']=='China']

# %%
china
# Out:
#                                                    MainBranch  \
# ResponseId
# 10279                          I am a developer by profession
# 11128                          I am a developer by profession
# 15164                          I am a developer by profession
# 16935                          I am a developer by profession
# 16963                  I am a student who is learning to code
# 17929                          I am a developer by profession
# 18859                  I am a student who is learning to code
# 19070                             I code primarily as a hobby
# 19105                          I am a developer by profession
# 22102                          I am a developer by profession
# 22280                          I am a developer by profession
# 22395                          I am a developer by profession
# 23050                          I am a developer by profession
# 23641       I am not primarily a developer, but I write co...
# ...

# %%
stack['Trans'].map({'Yes':'True','No':'False'})
# Out:
# ResponseId
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
#          ...
# 83435    False
# 83436    False
# 83437    False
# 83438    False
# 83439    False
# Name: Trans, Length: 83439, dtype: object

# %%
stack.sort_values(by='Country', inplace=True)

# %%
stack.head(3)
# Out:
#                                         MainBranch  \
# ResponseId
# 37432       I am a student who is learning to code
# 11462               I am a developer by profession
# 67131               I am a developer by profession
#
#                                     Employment      Country US_State  \
# ResponseId
# 37432                       Student, part-time  Afghanistan      NaN
# 11462       Not employed, but looking for work  Afghanistan      NaN
# 67131                                      NaN  Afghanistan      NaN
#
#            UK_Country                                          EdLevel  \
# ResponseId
# 37432             NaN  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 11462             NaN     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 67131             NaN                                              NaN
#
#                       Age1stCode  \
# ResponseId
# 37432       Younger than 5 years
# 11462              11 - 17 years
# 67131                        NaN
#
# ...

# %%
stack['ConvertedCompYearly'].mean()
# Out:
# 118426.15289044488

# %%
stack['ConvertedCompYearly'].median()
# Out:
# 56211.0

# %%
stack.dropna()
# Out:
# Empty DataFrame
# Columns: [MainBranch, Employment, Country, US_State, UK_Country, EdLevel, Age1stCode, LearnCode, YearsCode, YearsCodePro, DevType, OrgSize, Currency, CompTotal, CompFreq, LanguageHaveWorkedWith, LanguageWantToWorkWith, DatabaseHaveWorkedWith, DatabaseWantToWorkWith, PlatformHaveWorkedWith, PlatformWantToWorkWith, WebframeHaveWorkedWith, WebframeWantToWorkWith, MiscTechHaveWorkedWith, MiscTechWantToWorkWith, ToolsTechHaveWorkedWith, ToolsTechWantToWorkWith, NEWCollabToolsHaveWorkedWith, NEWCollabToolsWantToWorkWith, OpSys, NEWStuck, NEWSOSites, SOVisitFreq, SOAccount, SOPartFreq, SOComm, NEWOtherComms, Age, Gender, Trans, Sexuality, Ethnicity, Accessibility, MentalHealth, SurveyLength, SurveyEase, ConvertedCompYearly]
# Index: []
#
# [0 rows x 47 columns]

# %%
stack.dropna(axis=1)
# Out:
#                                                    MainBranch      Country
# ResponseId
# 37432                  I am a student who is learning to code  Afghanistan
# 11462                          I am a developer by profession  Afghanistan
# 67131                          I am a developer by profession  Afghanistan
# 62971       I am not primarily a developer, but I write co...  Afghanistan
# 14883                          I am a developer by profession  Afghanistan
# ...                                                       ...          ...
# 13195                          I am a developer by profession     Zimbabwe
# 80997                             I code primarily as a hobby     Zimbabwe
# 73742                          I am a developer by profession     Zimbabwe
# 73193                          I am a developer by profession     Zimbabwe
# 38429                          I am a developer by profession     Zimbabwe
#
# [83439 rows x 2 columns]

# %%
stack.dropna(axis=0)
# Out:
# Empty DataFrame
# Columns: [MainBranch, Employment, Country, US_State, UK_Country, EdLevel, Age1stCode, LearnCode, YearsCode, YearsCodePro, DevType, OrgSize, Currency, CompTotal, CompFreq, LanguageHaveWorkedWith, LanguageWantToWorkWith, DatabaseHaveWorkedWith, DatabaseWantToWorkWith, PlatformHaveWorkedWith, PlatformWantToWorkWith, WebframeHaveWorkedWith, WebframeWantToWorkWith, MiscTechHaveWorkedWith, MiscTechWantToWorkWith, ToolsTechHaveWorkedWith, ToolsTechWantToWorkWith, NEWCollabToolsHaveWorkedWith, NEWCollabToolsWantToWorkWith, OpSys, NEWStuck, NEWSOSites, SOVisitFreq, SOAccount, SOPartFreq, SOComm, NEWOtherComms, Age, Gender, Trans, Sexuality, Ethnicity, Accessibility, MentalHealth, SurveyLength, SurveyEase, ConvertedCompYearly]
# Index: []
#
# [0 rows x 47 columns]
